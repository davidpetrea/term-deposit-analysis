# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv("./data/clean_data.csv")
data = data.dropna()
data.rename(columns={'y': 'subscribed'}, inplace=True)

data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13216 entries, 0 to 13215
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             13216 non-null  float64
#  1   job             13216 non-null  object
#  2   marital         13216 non-null  object
#  3   education       13216 non-null  object
#  4   default         13216 non-null  object
#  5   housing         13216 non-null  object
#  6   loan            13216 non-null  object
#  7   contact         13216 non-null  object
#  8   month           13216 non-null  object
#  9   day_of_week     13216 non-null  object
#  10  campaign        13216 non-null  float64
#  11  pdays           13216 non-null  float64
#  12  previous        13216 non-null  float64
#  13  poutcome        13216 non-null  object
#  14  emp.var.rate    13216 non-null  float64
#  15  cons.price.idx  13216 non-null  float64
#  16  cons.conf.idx   13216 non-null  float64
#  17  euribor3m       13216 non-null  float64
#  18  nr.employed     13216 non-null  float64
#  19  subscribed      13216 non-null  object
#  20  year            13216 non-null  int64
#  21  date            13216 non-null  object
# dtypes: float64(9), int64(1), object(12)
# memory usage: 2.3+ MB
#     age            job  marital            education  default housing loan  \
# 0  38.0       services  married          high.school       no     yes   no
# 1  33.0    blue-collar  married             basic.6y       no     yes   no
# 2  43.0  self-employed  married          high.school  unknown     yes   no
# 3  31.0     technician  married  professional.course       no     yes   no
# 4  43.0  self-employed  married          high.school  unknown      no   no
#
#     contact month day_of_week  ...  previous     poutcome  emp.var.rate  \
# 0  cellular   apr         wed  ...       0.0  nonexistent          -1.8
# 1  cellular   apr         wed  ...       0.0  nonexistent          -1.8
# 2  cellular   apr         wed  ...       0.0  nonexistent          -1.8
# 3  cellular   apr         wed  ...       0.0  nonexistent          -1.8
# 4  cellular   apr         wed  ...       0.0  nonexistent          -1.8
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed  year  \
# 0         93.075          -47.1      1.498       5099.1          no  2009
# 1         93.075          -47.1      1.498       5099.1         yes  2009
# 2         93.075          -47.1      1.498       5099.1          no  2009
# 3         93.075          -47.1      1.498       5099.1          no  2009
# 4         93.075          -47.1      1.498       5099.1          no  2009
#
#          date
# 0  2009-04-01
# 1  2009-04-01
# 2  2009-04-01
# 3  2009-04-01
# 4  2009-04-01
#
# [5 rows x 22 columns]

# %%
data.groupby('marital').count()

#unknown marital status will be rolled into married

data.loc[(data.marital == 'unknown'), 'marital'] = 'married'

# %%
data.groupby('job').count()

#unknown job category will be rolled into admin

data.loc[(data.job == 'unknown'), 'job'] = 'admin.'
# Out:
#                 age  marital  education  default  housing  loan  contact  \
# job
# admin.         3591     3591       3591     3591     3591  3591     3591
# blue-collar    2760     2760       2760     2760     2760  2760     2760
# entrepreneur    389      389        389      389      389   389      389
# housemaid       233      233        233      233      233   233      233
# management      877      877        877      877      877   877      877
# retired         890      890        890      890      890   890      890
# self-employed   416      416        416      416      416   416      416
# services       1245     1245       1245     1245     1245  1245     1245
# student         657      657        657      657      657   657      657
# technician     1812     1812       1812     1812     1812  1812     1812
# unemployed      346      346        346      346      346   346      346
#
#                month  day_of_week  campaign  ...  previous  poutcome  \
# job                                          ...
# admin.          3591         3591      3591  ...      3591      3591
# blue-collar     2760         2760      2760  ...      2760      2760
# entrepreneur     389          389       389  ...       389       389
# housemaid        233          233       233  ...       233       233
# management       877          877       877  ...       877       877
# retired          890          890       890  ...       890       890
# self-employed    416          416       416  ...       416       416
# services        1245         1245      1245  ...      1245      1245
# student          657          657       657  ...       657       657
# technician      1812         1812      1812  ...      1812      1812
# unemployed       346          346       346  ...       346       346
#
#                emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# job
# admin.                 3591            3591           3591       3591
# blue-collar            2760            2760           2760       2760
# entrepreneur            389             389            389        389
# housemaid               233             233            233        233
# management              877             877            877        877
# retired                 890             890            890        890
# self-employed           416             416            416        416
# services               1245            1245           1245       1245
# student                 657             657            657        657
# technician             1812            1812           1812       1812
# unemployed              346             346            346        346
#
#                nr.employed  subscribed  year  date
# job
# admin.                3591        3591  3591  3591
# blue-collar           2760        2760  2760  2760
# entrepreneur           389         389   389   389
# housemaid              233         233   233   233
# management             877         877   877   877
# retired                890         890   890   890
# self-employed          416         416   416   416
# services              1245        1245  1245  1245
# student                657         657   657   657
# technician            1812        1812  1812  1812
# unemployed             346         346   346   346
#
# [11 rows x 21 columns]

# %%
data.groupby('education').count()

#combine illiterare with unknown, illiterate is not significant by itself 

data.loc[(data.education == 'illiterate'), 'education'] = 'unknown'
data.groupby('education').count()
# Out:
#                       age   job  marital  default  housing  loan  contact  \
# education
# basic.4y             1209  1209     1209     1209     1209  1209     1209
# basic.6y              674   674      674      674      674   674      674
# basic.9y             1878  1878     1878     1878     1878  1878     1878
# high.school          3258  3258     3258     3258     3258  3258     3258
# professional.course  1550  1550     1550     1550     1550  1550     1550
# university.degree    4060  4060     4060     4060     4060  4060     4060
# unknown               587   587      587      587      587   587      587
#
#                      month  day_of_week  campaign  ...  previous  poutcome  \
# education                                          ...
# basic.4y              1209         1209      1209  ...      1209      1209
# basic.6y               674          674       674  ...       674       674
# basic.9y              1878         1878      1878  ...      1878      1878
# high.school           3258         3258      3258  ...      3258      3258
# professional.course   1550         1550      1550  ...      1550      1550
# university.degree     4060         4060      4060  ...      4060      4060
# unknown                587          587       587  ...       587       587
#
#                      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# education
# basic.4y                     1209            1209           1209       1209
# basic.6y                      674             674            674        674
# basic.9y                     1878            1878           1878       1878
# high.school                  3258            3258           3258       3258
# professional.course          1550            1550           1550       1550
# university.degree            4060            4060           4060       4060
# unknown                       587             587            587        587
#
#                      nr.employed  subscribed  year  date
# education
# basic.4y                    1209        1209  1209  1209
# basic.6y                     674         674   674   674
# basic.9y                    1878        1878  1878  1878
# high.school                 3258        3258  3258  3258
# professional.course         1550        1550  1550  1550
# university.degree           4060        4060  4060  4060
# unknown                      587         587   587   587
#
# [7 rows x 21 columns]

# %%
data.groupby('loan').count()

#combine illiterare with unknown, illiterate is not significant by itself 

data.loc[(data.loan == 'unknown'), 'loan'] = 'no'
data.groupby('loan').count()
# Out:
#         age    job  marital  education  default  housing  contact  month  \
# loan
# no    11205  11205    11205      11205    11205    11205    11205  11205
# yes    2011   2011     2011       2011     2011     2011     2011   2011
#
#       day_of_week  campaign  ...  previous  poutcome  emp.var.rate  \
# loan                         ...
# no          11205     11205  ...     11205     11205         11205
# yes          2011      2011  ...      2011      2011          2011
#
#       cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed  \
# loan
# no             11205          11205      11205        11205       11205
# yes             2011           2011       2011         2011        2011
#
#        year   date
# loan
# no    11205  11205
# yes    2011   2011
#
# [2 rows x 21 columns]

# %%
data.groupby('housing').count()

#combine illiterare with unknown, illiterate is not significant by itself 

data.loc[(data.housing == 'unknown'), 'housing'] = 'no'
data.groupby('housing').count()
# Out:
#           age   job  marital  education  default  loan  contact  month  \
# housing
# no       5785  5785     5785       5785     5785  5785     5785   5785
# yes      7431  7431     7431       7431     7431  7431     7431   7431
#
#          day_of_week  campaign  ...  previous  poutcome  emp.var.rate  \
# housing                         ...
# no              5785      5785  ...      5785      5785          5785
# yes             7431      7431  ...      7431      7431          7431
#
#          cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed  \
# housing
# no                 5785           5785       5785         5785        5785
# yes                7431           7431       7431         7431        7431
#
#          year  date
# housing
# no       5785  5785
# yes      7431  7431
#
# [2 rows x 21 columns]

# %%
data.groupby('default').count()

#combine illiterare with unknown, illiterate is not significant by itself 

# data.loc[(data.housing == 'unknown'), 'housing'] = 'no'
# data.groupby('housing').count()
# Out:
#            age    job  marital  education  housing   loan  contact  month  \
# default
# no       11807  11807    11807      11807    11807  11807    11807  11807
# unknown   1409   1409     1409       1409     1409   1409     1409   1409
#
#          day_of_week  campaign  ...  previous  poutcome  emp.var.rate  \
# default                         ...
# no             11807     11807  ...     11807     11807         11807
# unknown         1409      1409  ...      1409      1409          1409
#
#          cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed  \
# default
# no                11807          11807      11807        11807       11807
# unknown            1409           1409       1409         1409        1409
#
#           year   date
# default
# no       11807  11807
# unknown   1409   1409
#
# [2 rows x 21 columns]

# %%
def separate_variables(df):
    numeric_vars = df.select_dtypes(include=['float64', 'int64'])
    categorical_vars = df.select_dtypes(include=['object'])
    return numeric_vars, categorical_vars

numeric_df, categorical_df = separate_variables(data)

def plot_histogram(data, column, y):
    plt.figure(figsize=(8, 6)) 
    sns.countplot(x=column,hue=y, data=data) 
    plt.title(f'Histogram of {column} by {y}', fontsize=14)  
    plt.xlabel(column, fontsize=12) 
    plt.ylabel('Frequency', fontsize=12)  
    plt.xticks(rotation='vertical',fontsize=10)  
    plt.yticks(fontsize=10)  
    plt.show()

for column in categorical_df.columns:
    plot_histogram(data, column, y='subscribed')

# %%
# At this point, data is ready for sampling

# validation data - from 2010-09-01 to latest

data.info()
validation_data = data.loc[data['date'] >= '2010-09-01']

validation_data.to_csv('./data/validation_set.csv', index=False)
validation_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13216 entries, 0 to 13215
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             13216 non-null  float64
#  1   job             13216 non-null  object
#  2   marital         13216 non-null  object
#  3   education       13216 non-null  object
#  4   default         13216 non-null  object
#  5   housing         13216 non-null  object
#  6   loan            13216 non-null  object
#  7   contact         13216 non-null  object
#  8   month           13216 non-null  object
#  9   day_of_week     13216 non-null  object
#  10  campaign        13216 non-null  float64
#  11  pdays           13216 non-null  float64
#  12  previous        13216 non-null  float64
#  13  poutcome        13216 non-null  object
#  14  emp.var.rate    13216 non-null  float64
#  15  cons.price.idx  13216 non-null  float64
#  16  cons.conf.idx   13216 non-null  float64
#  17  euribor3m       13216 non-null  float64
#  18  nr.employed     13216 non-null  float64
#  19  subscribed      13216 non-null  object
#  20  year            13216 non-null  int64
#  21  date            13216 non-null  object
# dtypes: float64(9), int64(1), object(12)
# memory usage: 2.8+ MB
#         age          job  marital            education default housing loan  \
# 12581  64.0      retired  married  professional.course      no     yes   no
# 12582  72.0      retired  married  professional.course      no      no   no
# 12583  34.0       admin.  married    university.degree      no     yes   no
# 12584  69.0      retired  married          high.school      no     yes  yes
# 12585  33.0   technician  married  professional.course      no     yes   no
# ...     ...          ...      ...                  ...     ...     ...  ...
# 13211  72.0      retired  married  professional.course      no     yes   no
# 13212  46.0  blue-collar  married  professional.course      no      no   no
# 13213  56.0      retired  married    university.degree      no     yes   no
# 13214  44.0   technician  married  professional.course      no      no   no
# 13215  72.0      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  previous     poutcome  emp.var.rate  \
# 12581  cellular   sep         wed  ...       0.0  nonexistent          -1.1
# 12582  cellular   sep         wed  ...       1.0      failure          -1.1
# 12583  cellular   sep         wed  ...       2.0      failure          -1.1
# 12584  cellular   sep         wed  ...       2.0      success          -1.1
# 12585  cellular   sep         wed  ...       0.0  nonexistent          -1.1
# ...         ...   ...         ...  ...       ...          ...           ...
# 13211  cellular   nov         fri  ...       0.0  nonexistent          -1.1
# 13212  cellular   nov         fri  ...       0.0  nonexistent          -1.1
# 13213  cellular   nov         fri  ...       0.0  nonexistent          -1.1
# 13214  cellular   nov         fri  ...       0.0  nonexistent          -1.1
# 13215  cellular   nov         fri  ...       1.0      failure          -1.1
#
#       cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed  year  \
# 12581         94.199          -37.5      0.886       4963.6         yes  2010
# 12582         94.199          -37.5      0.886       4963.6          no  2010
# 12583         94.199          -37.5      0.886       4963.6          no  2010
# 12584         94.199          -37.5      0.886       4963.6         yes  2010
# 12585         94.199          -37.5      0.886       4963.6         yes  2010
# ...              ...            ...        ...          ...         ...   ...
# 13211         94.767          -50.8      1.028       4963.6         yes  2010
# 13212         94.767          -50.8      1.028       4963.6          no  2010
# 13213         94.767          -50.8      1.028       4963.6          no  2010
# 13214         94.767          -50.8      1.028       4963.6         yes  2010
# 13215         94.767          -50.8      1.028       4963.6          no  2010
#
#              date
# 12581  2010-09-01
# 12582  2010-09-01
# 12583  2010-09-01
# 12584  2010-09-01
# 12585  2010-09-01
# ...           ...
# 13211  2010-11-01
# 13212  2010-11-01
# 13213  2010-11-01
# 13214  2010-11-01
# 13215  2010-11-01
#
# [635 rows x 22 columns]

# %%
#Sampling train/test

model_data = data.loc[data['date'] < '2010-09-01']

from sklearn.model_selection import train_test_split

# Split the dataset into training and test sets
training_data, testing_data = train_test_split(model_data, test_size=0.3, random_state=42)

# Print the shapes of the resulting sets
print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")

testing_data.to_csv('./data/testing_set.csv', index=False)


#Apply sampling techniques to training data

training_data.to_csv('./data/training_set.csv', index=False)
# Out:
# No. of training examples: 8806
# No. of testing examples: 3775
